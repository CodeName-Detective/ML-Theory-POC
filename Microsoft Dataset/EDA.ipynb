# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Microsoft_Data.csv')
df
# Out:
#                       MachineIdentifier   ProductName EngineVersion  \
# 0      0000028988387b115f69f31a3bf04f09  win8defender   1.1.15100.1
# 1      000007535c3f730efa9ea0b7ef1bd645  win8defender   1.1.14600.4
# 2      000007905a28d863f6d0d597892cd692  win8defender   1.1.15100.1
# 3      00000b11598a75ea8ba1beea8459149f  win8defender   1.1.15100.1
# 4      000014a5f00daa18e76b81417eeb99fc  win8defender   1.1.15100.1
# 5      000016191b897145d069102325cab760  win8defender   1.1.15100.1
# 6      0000161e8abf8d8b89c5ab8787fd712b  win8defender   1.1.15100.1
# 7      000019515bc8f95851aff6de873405e8  win8defender   1.1.15100.1
# 8      00001a027a0ab970c408182df8484fce  win8defender   1.1.15200.1
# 9      00001a18d69bb60bda9779408dcf02ac  win8defender   1.1.15100.1
# 10     00001b3b3cf8c8c079a272ce51031753  win8defender   1.1.15100.1
# 11     00001b924fcc6922321cfadbafd8a91a  win8defender   1.1.15100.1
# 12     00001f26e9e5775277d6231fc6ac9e70  win8defender   1.1.15100.1
# ...

# %%
df.shape
# Out:
# (56756, 83)

# %%
from sklearn.model_selection import train_test_split
y = df['HasDetections']
df.drop(columns=['HasDetections'],axis=1)
df,X_test,y_train,y_test = train_test_split(df,y,test_size=0.2,random_state=42)

# %% [markdown]
# ### "MachineIdentifier" Columns

# %%
df['MachineIdentifier'].nunique()
# Out:
# 45404

# %% [markdown]
# - Dropping the column as each and every value is unique

# %%
df.drop('MachineIdentifier',axis=1,inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %% [markdown]
# ### "ProductName" Column

# %%
df['ProductName'].nunique()
# Out:
# 2

# %%
df['ProductName'].value_counts()
# Out:
# win8defender    44896
# mse               508
# Name: ProductName, dtype: int64

# %%
productName_dummies = pd.get_dummies(df['ProductName'],prefix='ProductName')
df.join(productName_dummies)
# Out:
#         ProductName EngineVersion        AppVersion  AvSigVersion  IsBeta  \
# 5329   win8defender   1.1.15200.1   4.18.1807.18075  1.275.1080.0       0
# 39862  win8defender   1.1.15200.1   4.18.1807.18075   1.275.852.0       0
# 46411  win8defender   1.1.15200.1   4.18.1807.18075  1.275.1578.0       0
# 31801  win8defender   1.1.14600.4   4.10.14393.1794    1.263.14.0       0
# 3693   win8defender   1.1.15100.1      4.11.15063.0   1.273.781.0       0
# 42612  win8defender   1.1.14800.3    4.9.10586.1106   1.267.713.0       0
# 55131  win8defender   1.1.15100.1   4.8.10240.17443  1.273.1144.0       0
# 27337  win8defender   1.1.15200.1   4.18.1807.18075   1.275.388.0       0
# 7547   win8defender   1.1.15200.1   4.18.1807.18075   1.275.493.0       0
# 53038  win8defender   1.1.15200.1      4.13.17134.1   1.275.727.0       0
# 30674  win8defender   1.1.15200.1   4.18.1807.18075  1.275.1140.0       0
# 1467   win8defender   1.1.15200.1   4.18.1807.18075  1.275.1448.0       0
# ...

# %%
df.drop('ProductName',axis=1,inplace=True)

# %% [markdown]
# - Destorying the productName_dummies

# %%
# %xdel productName_dummies

# %% [markdown]
# ### "EngineVersion" Columns

# %%
df['EngineVersion'].value_counts()
# Out:
# 1.1.15200.1    19580
# 1.1.15100.1    18778
# 1.1.15000.2     1340
# 1.1.14901.4     1038
# 1.1.14600.4      788
# 1.1.14800.3      665
# 1.1.15300.6      636
# 1.1.14104.0      485
# 1.1.13504.0      361
# 1.1.15300.5      353
# 1.1.14700.5      222
# 1.1.14500.5      215
# 1.1.14405.2      197
# 1.1.14306.0      116
# 1.1.14003.0       78
# 1.1.14202.0       77
# 1.1.13303.0       65
# 1.1.13903.0       59
# 1.1.13407.0       53
# 1.1.13804.0       49
# 1.1.13601.0       33
# 1.1.13103.0       25
# 1.1.13704.0       23
# 1.1.13000.0       22
# 1.1.13701.0       20
# 1.1.14305.0       20
# 1.1.12902.0       20
# 1.1.13202.0       19
# 1.1.15000.1       18
# 1.1.12805.0       10
# 1.1.14800.1       10
# 1.1.14700.3        9
# 1.1.14901.3        9
# 1.1.14700.4        7
# 1.1.14201.0        2
# 1.1.14103.0        1
# 1.1.14303.0        1
# Name: EngineVersion, dtype: int64

# %%
df.EngineVersion.nunique()
# Out:
# 37

# %%
df.EngineVersion.dtype
# Out:
# dtype('O')

# %%
df.EngineVersion.str.len()
# Out:
# 5329     11
# 39862    11
# 46411    11
# 31801    11
# 3693     11
# 42612    11
# 55131    11
# 27337    11
# 7547     11
# 53038    11
# 30674    11
# 1467     11
# 41192    11
# 36205    11
# 44213    11
# 5260     11
# 48720    11
# 8952     11
# 36217    11
# 8904     11
# 2265     11
# 43379    11
# 52801    11
# 34904    11
# 21960    11
# 22329    11
# 52834    11
# 36111    11
# 13970    11
# 37800    11
#          ..
# 41434    11
# 27480    11
# 6396     11
# 28693    11
# 19769    11
# 53707    11
# 17568    11
# 39188    11
# 37819    11
# 5311     11
# 2433     11
# 56101    11
# 769      11
# 1685     11
# 41090    11
# 16023    11
# 44131    11
# 47191    11
# 21962    11
# 37194    11
# 16850    11
# 6265     11
# 54886    11
# 11284    11
# 44732    11
# 54343    11
# 38158    11
# 860      11
# 15795    11
# 56422    11
# Name: EngineVersion, Length: 45404, dtype: int64

# %%
df.EngineVersion = df.EngineVersion.str[4:9]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
df.EngineVersion.value_counts()
# Out:
# 15200    19580
# 15100    18778
# 15000     1358
# 14901     1047
# 15300      989
# 14600      788
# 14800      675
# 14104      485
# 13504      361
# 14700      238
# 14500      215
# 14405      197
# 14306      116
# 14003       78
# 14202       77
# 13303       65
# 13903       59
# 13407       53
# 13804       49
# 13601       33
# 13103       25
# 13704       23
# 13000       22
# 14305       20
# 12902       20
# 13701       20
# 13202       19
# 12805       10
# 14201        2
# 14103        1
# 14303        1
# Name: EngineVersion, dtype: int64

# %%
df.EngineVersion.nunique()
# Out:
# 31

# %%
df.EngineVersion.isnull().sum()
# Out:
# 0

# %% [markdown]
# ### AppVersion

# %%
df.AppVersion.isnull().sum()
# Out:
# 0

# %%
df.AppVersion.nunique()
# Out:
# 76

# %%
df['AppVersion'].dtype
# Out:
# dtype('O')

# %%
df.AppVersion
# Out:
# 5329      4.18.1807.18075
# 39862     4.18.1807.18075
# 46411     4.18.1807.18075
# 31801     4.10.14393.1794
# 3693         4.11.15063.0
# 42612      4.9.10586.1106
# 55131     4.8.10240.17443
# 27337     4.18.1807.18075
# 7547      4.18.1807.18075
# 53038        4.13.17134.1
# 30674     4.18.1807.18075
# 1467      4.18.1807.18075
# 41192     4.18.1806.18062
# 36205     4.18.1807.18075
# 44213     4.18.1807.18075
# 5260      4.18.1807.18075
# 48720     4.18.1807.18075
# 8952      4.18.1807.18075
# 36217     4.18.1806.18062
# 8904         4.13.17134.1
# 2265     4.16.17656.18052
# 43379     4.18.1807.18075
# 52801     4.18.1807.18075
# 34904     4.18.1807.18075
# 21960     4.18.1807.18075
# 22329     4.18.1806.18062
# 52834     4.18.1807.18075
# 36111     4.18.1807.18075
# 13970     4.18.1807.18075
# 37800    4.14.17639.18041
#                ...
# 41434       4.12.16299.15
# 27480     4.18.1807.18075
# 6396      4.18.1807.18075
# 28693    4.16.17656.18052
# ...

# %% [markdown]
# # AvSigVersion

# %%
df['AvSigVersion'].isnull().sum()
# Out:
# 0

# %%
df['AvSigVersion'].nunique()
# Out:
# 2980

# %%
#df.AvSigVersion = df.AvSigVersion.str[:-2]

# %% [markdown]
# # IsBeta

# %%
df['IsBeta'].isnull().sum()
# Out:
# 0

# %%
df['IsBeta'].nunique()
# Out:
# 1

# %% [markdown]
# - As all are of same class this feature is not useful

# %%
df.drop('IsBeta',axis=1,inplace=True)

# %% [markdown]
# # RtpStateBitfield

# %%
df['RtpStateBitfield'].isnull().sum()
# Out:
# 156

# %%
df['RtpStateBitfield'].dtype
# Out:
# dtype('float64')

# %%
df['RtpStateBitfield']
# Out:
# 5329     7.0
# 39862    7.0
# 46411    7.0
# 31801    7.0
# 3693     7.0
# 42612    7.0
# 55131    7.0
# 27337    7.0
# 7547     7.0
# 53038    7.0
# 30674    7.0
# 1467     7.0
# 41192    7.0
# 36205    7.0
# 44213    7.0
# 5260     7.0
# 48720    7.0
# 8952     7.0
# 36217    7.0
# 8904     7.0
# 2265     7.0
# 43379    7.0
# 52801    7.0
# 34904    7.0
# 21960    7.0
# 22329    7.0
# 52834    7.0
# 36111    7.0
# 13970    7.0
# 37800    7.0
#         ...
# 41434    0.0
# 27480    7.0
# 6396     7.0
# 28693    7.0
# 19769    NaN
# 53707    7.0
# 17568    7.0
# 39188    7.0
# 37819    7.0
# 5311     7.0
# 2433     7.0
# 56101    7.0
# 769      7.0
# 1685     7.0
# 41090    7.0
# 16023    7.0
# 44131    7.0
# 47191    7.0
# 21962    7.0
# 37194    7.0
# 16850    7.0
# 6265     7.0
# 54886    7.0
# 11284    7.0
# 44732    7.0
# 54343    7.0
# 38158    7.0
# 860      7.0
# 15795    7.0
# 56422    7.0
# Name: RtpStateBitfield, Length: 45404, dtype: float64

# %%
df['RtpStateBitfield'].nunique()
# Out:
# 6

# %%
df['RtpStateBitfield'].unique()
# Out:
# array([ 7.,  0., nan,  3.,  5.,  8.,  1.])

# %%
df['HasDetections'].groupby(df['RtpStateBitfield'].fillna(-1)).value_counts()
# Out:
# RtpStateBitfield  HasDetections
# -1.0              0                  111
#                   1                   85
#  0.0              0                  742
#                   1                  506
#  1.0              0                    6
#                   1                    2
#  3.0              0                   13
#                   1                    6
#  5.0              0                   98
#                   1                   22
#  7.0              1                27740
#                   0                27298
#  8.0              1                   91
#                   0                   36
# Name: HasDetections, dtype: int64

# %%
df['RtpStateBitfield'] = df['RtpStateBitfield'].astype('object')

# %%
df['RtpStateBitfield'].fillna(df['RtpStateBitfield'].mode()[0],inplace=True)

# %%
df['RtpStateBitfield'].isnull().sum()
# Out:
# 0

# %%
dummies = pd.get_dummies(df['RtpStateBitfield'],prefix='RtpStateBitfield')
dummies
# Out:
#        RtpStateBitfield_0.0  RtpStateBitfield_1.0  RtpStateBitfield_3.0  \
# 0                         0                     0                     0
# 1                         0                     0                     0
# 2                         0                     0                     0
# 3                         0                     0                     0
# 4                         0                     0                     0
# 5                         0                     0                     0
# 6                         0                     0                     0
# 7                         0                     0                     0
# 8                         0                     0                     0
# 9                         0                     0                     0
# 10                        0                     0                     0
# 11                        0                     0                     0
# ...

# %%
df = df.join(dummies)
df.columns
# Out:
# Index(['EngineVersion', 'AppVersion', 'AvSigVersion', 'RtpStateBitfield',
#        'IsSxsPassiveMode', 'DefaultBrowsersIdentifier',
#        'AVProductStatesIdentifier', 'AVProductsInstalled', 'AVProductsEnabled',
#        'HasTpm', 'CountryIdentifier', 'CityIdentifier',
#        'OrganizationIdentifier', 'GeoNameIdentifier',
#        'LocaleEnglishNameIdentifier', 'Platform', 'Processor', 'OsVer',
#        'OsBuild', 'OsSuite', 'OsPlatformSubRelease', 'OsBuildLab',
#        'SkuEdition', 'IsProtected', 'AutoSampleOptIn', 'PuaMode', 'SMode',
#        'IeVerIdentifier', 'SmartScreen', 'Firewall', 'UacLuaenable',
#        'Census_MDC2FormFactor', 'Census_DeviceFamily',
#        'Census_OEMNameIdentifier', 'Census_OEMModelIdentifier',
#        'Census_ProcessorCoreCount', 'Census_ProcessorManufacturerIdentifier',
#        'Census_ProcessorModelIdentifier', 'Census_ProcessorClass',
#        'Census_PrimaryDiskTotalCapacity', 'Census_PrimaryDiskTypeName',
# ...

# %%
df.drop('RtpStateBitfield',axis=1,inplace=True)

# %% [markdown]
# # IsSxsPassiveMode

# %%
df['IsSxsPassiveMode'].isnull().sum()
# Out:
# 0

# %%
df['IsSxsPassiveMode'].nunique()
# Out:
# 2

# %%
df['IsSxsPassiveMode'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['HasDetections'].groupby(df['IsSxsPassiveMode']).value_counts()
# Out:
# IsSxsPassiveMode  HasDetections
# 0                 1                28031
#                   0                27709
# 1                 0                  595
#                   1                  421
# Name: HasDetections, dtype: int64

# %% [markdown]
# # DefaultBrowsersIdentifier

# %%
(df['DefaultBrowsersIdentifier'].isnull().sum()/df.shape[0])*100
# Out:
# 95.11417295087745

# %% [markdown]
# -  As 95% of them are missing values better to delete this columns

# %%
df.drop('DefaultBrowsersIdentifier',axis=1,inplace=True)

# %% [markdown]
# # AVProductStatesIdentifier

# %%
df['AVProductStatesIdentifier'].isnull().sum()
# Out:
# 222

# %%
df['AVProductStatesIdentifier'].head()
# Out:
# 0    53447.0
# 1    53447.0
# 2    53447.0
# 3    53447.0
# 4    53447.0
# Name: AVProductStatesIdentifier, dtype: float64

# %%
df['AVProductStatesIdentifier'].nunique()
# Out:
# 1467

# %%
df['AVProductStatesIdentifier'] = df['AVProductStatesIdentifier'].astype('object')

# %%
df['HasDetections'].groupby(df['AVProductStatesIdentifier'].fillna(-1)).value_counts()
# Out:
# AVProductStatesIdentifier  HasDetections
# -1.0                       0                134
#                            1                 88
#  39.0                      0                  2
#  216.0                     0                  2
#                            1                  2
#  279.0                     1                  1
#  307.0                     0                  1
#  401.0                     0                  1
#  579.0                     0                  1
#  659.0                     1                  1
#  712.0                     0                  1
#  794.0                     0                  1
#  857.0                     0                  1
#  901.0                     0                  2
#  938.0                     0                  2
#                            1                  1
#  956.0                     1                  2
#  983.0                     1                  2
#                            0                  1
# ...

# %%
df.AVProductStatesIdentifier.dtype
# Out:
# dtype('O')

# %%
df['AVProductStatesIdentifier'].fillna(df['AVProductStatesIdentifier'].mode()[0],inplace=True)
